# %% [markdown]
# # Calculate interannotator agreement

# %% [markdown]
# ## Setup
#
# - Enable `%autoreload` for immediate reflection of utils library changes
# - Load credentials from the `.env` file
# - Configure the environment and establish connection to the Argilla server

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import argilla as rg
import matplotlib.pyplot as plt
import seaborn as sns
from archaeo_ner_greek.utils import get_argilla_client, load_credentials_from_env, get_dataset_as_dataframe
from archaeo_ner_greek.utils import prepare_iaa_data, calculate_ner_iaa, calculate_label_iaa, analyze_iaa_discrepancies
from archaeo_ner_greek.logging_config import setup_logging
import logging

# 1. Setup logging
setup_logging()

# 2. Load configuration from .env
env_values = load_credentials_from_env()

# 3. Establish connection to Argilla
if env_values:
    client = get_argilla_client(env_values)
else:
    logging.warning("Missing configuration in .env file.")
# Out:
# 2026-03-04 17:00:59,713 [INFO] root: Argilla: Logged in as prokopis with the role Role.owner

# %% [markdown]
# ## Loading Annotations from Argilla
#
# - Fetch the `archaeo_ner_greek` dataset
# - Convert records into a Pandas DataFrame using `utils.py`
# - Ensure all user responses (spans and suggestions) are included for analysis

# %%
# Define dataset and workspace
dataset_name = "archaeo_ner_greek"
workspace_name = "archaeo_ner_greek"

# Fetch the full dataframe with responses included
df = get_dataset_as_dataframe(
    client, 
    dataset_name=dataset_name, 
    workspace_name=workspace_name, 
    include_responses=True
)

# %% [markdown]
# ## Data Exploration & Quality Check
#
# - Visualize raw data before metric calculation
# - Use custom CSS styling for wrapping Greek text and response dictionaries
# - Manually verify annotation density and structure

# %%
# 1. Set display option to show full content instead of truncating (...)
pd.set_option('display.max_colwidth', None)

# 2. Select columns and apply styling for wrapping and vertical alignment
(df[["sentence_field", "responses"]].head(10).style
 .set_properties(**{
     'text-align': 'left',
     'white-space': 'pre-wrap',
     'vertical-align': 'top'
 })
 .set_table_styles([
     {'selector': 'th', 'props': [('font-weight', 'bold')]},
     {'selector': 'td.col0', 'props': [('width', '400px')]}, # Fixed width for sentence
     {'selector': 'td.col1', 'props': [('width', '600px')]}  # Fixed width for responses
 ])
)
# Out:
# <style type="text/css">
# #T_5e866 th {
#   font-weight: bold;
# }
# #T_5e866 td.col0 {
#   width: 400px;
# }
# #T_5e866 td.col1 {
#   width: 600px;
# }
# #T_5e866_row0_col0, #T_5e866_row0_col1, #T_5e866_row1_col0, #T_5e866_row1_col1, #T_5e866_row2_col0, #T_5e866_row2_col1, #T_5e866_row3_col0, #T_5e866_row3_col1, #T_5e866_row4_col0, #T_5e866_row4_col1, #T_5e866_row5_col0, #T_5e866_row5_col1, #T_5e866_row6_col0, #T_5e866_row6_col1, #T_5e866_row7_col0, #T_5e866_row7_col1, #T_5e866_row8_col0, #T_5e866_row8_col1, #T_5e866_row9_col0, #T_5e866_row9_col1 {
#   text-align: left;
#   white-space: pre-wrap;
#   vertical-align: top;
# }
# </style>
# <table id="T_5e866">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5e866_level0_col0" class="col_heading level0 col0" >sentence_field</th>
#       <th id="T_5e866_level0_col1" class="col_heading level0 col1" >responses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5e866_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5e866_row0_col0" class="data row0 col0" >Αργυρή δραχμή Απολλωνίας από την Ελέα</td>
#       <td id="T_5e866_row0_col1" class="data row0 col1" >[{'username': 'stalexan', 'user_id': '521e8843-81c7-40a6-92cd-26b6b2a25544', 'values': [{'label': 'MATERIAL', 'start': 0, 'end': 6}, {'label': 'LOCATION', 'start': 33, 'end': 37}, {'label': 'ARTEFACT', 'start': 7, 'end': 24}], 'status': <ResponseStatus.submitted: 'submitted'>}, {'username': 'stalexan', 'user_id': '521e8843-81c7-40a6-92cd-26b6b2a25544', 'values': 'ok.', 'status': <ResponseStatus.submitted: 'submitted'>}, {'username': 'sasi.dimopoulou', 'user_id': '9c6b0979-0cae-4583-be20-3bbc64e671fe', 'values': [{'label': 'LOCATION', 'start': 33, 'end': 37}, {'label': 'MATERIAL', 'start': 0, 'end': 6}, {'label': 'ARTEFACT', 'start': 7, 'end': 25}], 'status': <ResponseStatus.submitted: 'submitted'>}, {'username': 'sasi.dimopoulou', 'user_id': '9c6b0979-0cae-4583-be20-3bbc64e671fe', 'values': 'οκ', 'status': <ResponseStatus.submitted: 'submitted'>}]</td>
#     </tr>
#     <tr>
#       <th id="T_5e866_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5e866_row1_col0" class="data row1 col0" >Ασημένια δραχμή Απολλωνίας .</td>
#       <td id="T_5e866_row1_col1" class="data row1 col1" >[{'username': 'stalexan', 'user_id': '521e8843-81c7-40a6-92cd-26b6b2a25544', 'values': [{'label': 'MATERIAL', 'start': 0, 'end': 8}, {'label': 'ARTEFACT', 'start': 9, 'end': 26}], 'status': <ResponseStatus.submitted: 'submitted'>}, {'username': 'stalexan', 'user_id': '521e8843-81c7-40a6-92cd-26b6b2a25544', 'values': 'ok.', 'status': <ResponseStatus.submitted: 'submitted'>}, {'username': 'sasi.dimopoulou', 'user_id': '9c6b0979-0cae-4583-be20-3bbc64e671fe', 'values': [{'label': 'MATERIAL', 'start': 0, 'end': 8}, {'label': 'ARTEFACT', 'start': 9, 'end': 26}], 'status': <ResponseStatus.submitted: 'submitted'>}, {'username': 'sasi.dimopoulou', 'user_id': '9c6b0979-0cae-4583-be20-3bbc64e671fe', 'values': 'ΟΚ', 'status': <ResponseStatus.submitted: 'submitted'>}]</td>
#     </tr>
#     <tr>
#       <th id="T_5e866_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5e866_row2_col0" class="data row2 col0" >Εμπροσθότυπος : Αγελάδα προς τα δεξιά , θηλάζει το μοσχαράκι της .</td>
#       <td id="T_5e866_row2_col1" class="data row2 col1" >[{'username': 'stalexan', 'user_id': '521e8843-81c7-40a6-92cd-26b6b2a25544', 'values': [{'label': 'SPECIES', 'start': 16, 'end': 23}, {'label': 'SPECIES', 'start': 51, 'end': 60}], 'status': <ResponseStatus.submitted: 'submitted'>}, {'username': 'stalexan', 'user_id': '521e8843-81c7-40a6-92cd-26b6b2a25544', 'values': 'ok.', 'status': <ResponseStatus.submitted: 'submitted'>}, {'username': 'sasi.dimopoulou', 'user_id': '9c6b0979-0cae-4583-be20-3bbc64e671fe', 'values': [{'label': 'SPECIES', 'start': 16, 'end': 23}, {'label': 'SPECIES', 'start': 51, 'end': 60}], 'status': <ResponseStatus.submitted: 'submitted'>}, {'username': 'sasi.dimopoulou', 'user_id': '9c6b0979-0cae-4583-be20-3bbc64e671fe', 'values': 'οκ', 'status': <ResponseStatus.submitted: 'submitted'>}]</td>
#     </tr>
#     <tr>
#       <th id="T_5e866_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5e866_row3_col0" class="data row3 col0" >Συμβατικά δηλώνεται το έδαφος με μια απλή γραμμή .</td>
#       <td id="T_5e866_row3_col1" class="data row3 col1" >[{'username': 'stalexan', 'user_id': '521e8843-81c7-40a6-92cd-26b6b2a25544', 'values': [], 'status': <ResponseStatus.submitted: 'submitted'>}, {'username': 'stalexan', 'user_id': '521e8843-81c7-40a6-92cd-26b6b2a25544', 'values': 'ok.', 'status': <ResponseStatus.submitted: 'submitted'>}, {'username': 'sasi.dimopoulou', 'user_id': '9c6b0979-0cae-4583-be20-3bbc64e671fe', 'values': [], 'status': <ResponseStatus.submitted: 'submitted'>}, {'username': 'sasi.dimopoulou', 'user_id': '9c6b0979-0cae-4583-be20-3bbc64e671fe', 'values': 'οκ', 'status': <ResponseStatus.submitted: 'submitted'>}]</td>
#     </tr>
#     <tr>
#       <th id="T_5e866_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5e866_row4_col0" class="data row4 col0" >Πάνω από την αγελάδα η επιγραφή " ΔΟΝΑΞ " .</td>
#       <td id="T_5e866_row4_col1" class="data row4 col1" >[{'username': 'stalexan', 'user_id': '521e8843-81c7-40a6-92cd-26b6b2a25544', 'values': [{'label': 'SPECIES', 'start': 13, 'end': 20}, {'label': 'ARTEFACT', 'start': 23, 'end': 41}], 'status': <ResponseStatus.submitted: 'submitted'>}, {'username': 'stalexan', 'user_id': '521e8843-81c7-40a6-92cd-26b6b2a25544', 'values': 'ok.', 'status': <ResponseStatus.submitted: 'submitted'>}, {'username': 'sasi.dimopoulou', 'user_id': '9c6b0979-0cae-4583-be20-3bbc64e671fe', 'values': [{'label': 'SPECIES', 'start': 13, 'end': 20}, {'label': 'ARTEFACT', 'start': 23, 'end': 41}], 'status': <ResponseStatus.submitted: 'submitted'>}, {'username': 'sasi.dimopoulou', 'user_id': '9c6b0979-0cae-4583-be20-3bbc64e671fe', 'values': 'οκ', 'status': <ResponseStatus.submitted: 'submitted'>}]</td>
#     </tr>
#     <tr>
#       <th id="T_5e866_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5e866_row5_col0" class="data row5 col0" >Οπισθότυπος : Διπλό αστρικό κόσμημα σε οριζόντια διάταξη μέσα σε διπλό τετράγωνο πλαίσιο .</td>
#       <td id="T_5e866_row5_col1" class="data row5 col1" >[{'username': 'stalexan', 'user_id': '521e8843-81c7-40a6-92cd-26b6b2a25544', 'values': [{'label': 'ARTEFACT', 'start': 28, 'end': 35}], 'status': <ResponseStatus.submitted: 'submitted'>}, {'username': 'stalexan', 'user_id': '521e8843-81c7-40a6-92cd-26b6b2a25544', 'values': 'ok', 'status': <ResponseStatus.submitted: 'submitted'>}, {'username': 'sasi.dimopoulou', 'user_id': '9c6b0979-0cae-4583-be20-3bbc64e671fe', 'values': [{'label': 'ARTEFACT', 'start': 20, 'end': 35}], 'status': <ResponseStatus.submitted: 'submitted'>}, {'username': 'sasi.dimopoulou', 'user_id': '9c6b0979-0cae-4583-be20-3bbc64e671fe', 'values': 'οκ', 'status': <ResponseStatus.submitted: 'submitted'>}]</td>
#     </tr>
#     <tr>
#       <th id="T_5e866_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5e866_row6_col0" class="data row6 col0" >Το εθνικό της πόλης " ΑΠΟΛ " πάνω από την κεντρική παράσταση .</td>
#       <td id="T_5e866_row6_col1" class="data row6 col1" >[{'username': 'stalexan', 'user_id': '521e8843-81c7-40a6-92cd-26b6b2a25544', 'values': [{'label': 'ARTEFACT', 'start': 14, 'end': 28}], 'status': <ResponseStatus.submitted: 'submitted'>}, {'username': 'stalexan', 'user_id': '521e8843-81c7-40a6-92cd-26b6b2a25544', 'values': 'ok.', 'status': <ResponseStatus.submitted: 'submitted'>}, {'username': 'sasi.dimopoulou', 'user_id': '9c6b0979-0cae-4583-be20-3bbc64e671fe', 'values': [{'label': 'ARTEFACT', 'start': 14, 'end': 28}], 'status': <ResponseStatus.submitted: 'submitted'>}, {'username': 'sasi.dimopoulou', 'user_id': '9c6b0979-0cae-4583-be20-3bbc64e671fe', 'values': 'οκ', 'status': <ResponseStatus.submitted: 'submitted'>}]</td>
#     </tr>
#     <tr>
#       <th id="T_5e866_level0_row7" class="row_heading level0 row7" >7</th>

# %% [markdown]
# ## Structuring Data for IAA
#
# - Transform raw Argilla responses into entity triplets `(start, end, label)`
# - Group annotations by user using the `prepare_iaa_data` utility
# - Identify sentences ready for comparison (2+ annotators) versus those requiring more work

# %%
# 1. Prepare data for agreement analysis
iaa_results = prepare_iaa_data(df)
iaa_ready = iaa_results["ready"]

# 2. Map annotators for consistent reporting (A=stalexan, B=sasi.dimopoulou)
annotator_a = "stalexan"
annotator_b = "sasi.dimopoulou"
print(f"Mapping: A = {annotator_a}, B = {annotator_b}")

# 3. Report annotation status
print(f"✅ Sentences ready for IAA: {len(iaa_ready)}")
print(f"⚠️  Missing teammates (only 1 annotator): {len(iaa_results['missing_teammate'])}")
print(f"❌ Unannotated sentences: {len(iaa_results['unannotated'])}")
# Out:
# Mapping: A = stalexan, B = sasi.dimopoulou
# ✅ Sentences ready for IAA: 212
# ⚠️  Missing teammates (only 1 annotator): 0
# ❌ Unannotated sentences: 0

# %% [markdown]
# ## Pairwise Agreement Report (Global)
#
# - Calculate high-level consistency metrics between annotator pairs
# - **Sentence Match %**: Perfect sentence set-equality (including sentences with zero entities)
# - **Span F1-Score**: Standard NER benchmark for entity segment overlap

# %%
# Calculate and display pairwise agreement report
iaa_report = calculate_ner_iaa(iaa_ready)
iaa_report
# Out:
#                Annotator Pair  Sentences Compared  Perfect Matches  \
# 0  sasi.dimopoulou ↔ stalexan                 212              164
#
#   Sentence Match %  Span F1-Score
# 0            77.4%         0.9114

# %% [markdown]
# ## Label-Specific Agreement Breakdown
#
# - Breakdown agreement metrics (F1-score) for each individual label
# - Identify categories where annotation guidelines may require clarification or additional examples

# %%
# Calculate and display per-label agreement statistics using consistent A/B mapping
label_report = calculate_label_iaa(iaa_ready, annotators=[annotator_a, annotator_b])
label_report
# Out:
#       Label  Both  Only in A (stalexan)  Only in B (sasi.dimopoulou)  F1-Score
# 0  LOCATION    44                     2                            2    0.9565
# 1  MATERIAL    92                     7                            8    0.9246
# 2   CONTEXT   231                    20                           18    0.9240
# 3    PERSON    24                     3                            1    0.9231
# 4    PERIOD    83                     8                            8    0.9121
# 5   FEATURE    79                     9                            7    0.9080
# 6  ARTEFACT   176                    21                           25    0.8844
# 7   SPECIES    17                     2                            4    0.8500
# 8   OVERALL   746                    72                           73    0.9114

# %% [markdown]
# ## Discrepancy Analysis
#
# - Distinguish between classification errors (same span, different label) and boundary errors (overlapping spans)
# - Quantify total misses where an entity was identified by only one annotator

# %%
# Categorize disagreements into specific error types
discrepancy_report = analyze_iaa_discrepancies(iaa_ready, annotators=[annotator_a, annotator_b])
discrepancy_report
# Out:
#                            Count
# Exact Matches             746.00
# Label Mismatches            4.00
# Boundary Disagreements     63.00
# Total Misses (A only)       5.00
# Total Misses (B only)       9.00
# Boundary Char Diff (Avg)    4.41

# %% [markdown]
# ## Visualizations for Annotator Feedback
#
# - Generate graphical representations of agreement and disagreement
# - Compare performance across different entity categories
# - Visualize the distribution of specific error types to inform guideline refinement

# %%
# Set visual style
sns.set_theme(style="whitegrid")
plt.rcParams['font.family'] = 'DejaVu Sans'

fig, axes = plt.subplots(3, 1, figsize=(10, 18))

# 1. Label F1-Scores
label_data_clean = label_report[label_report["Label"] != "OVERALL"].sort_values("F1-Score", ascending=False)
sns.barplot(data=label_data_clean, x="F1-Score", y="Label", ax=axes[0], palette="viridis")
axes[0].set_title("IAA F1-Score per Label", fontsize=14, fontweight='bold')
axes[0].set_xlim(0, 1)

# 2. Agreement vs Disagreement Volume
label_counts = label_data_clean.melt(id_vars="Label", value_vars=["Both", f"Only in A ({annotator_a})", f"Only in B ({annotator_b})"], 
                                    var_name="Category", value_name="Count")
sns.barplot(data=label_counts, x="Count", y="Label", hue="Category", ax=axes[1], palette="muted")
axes[1].set_title("Annotation Volume Breakdown (Agreement vs Omissions)", fontsize=14, fontweight='bold')
axes[1].legend(title="Source", bbox_to_anchor=(1.05, 1), loc='upper left')

# 3. Discrepancy Types Distribution
discrepancy_data = discrepancy_report.reset_index()
discrepancy_data.columns = ["Error Type", "Count"]
sns.barplot(data=discrepancy_data, x="Count", y="Error Type", ax=axes[2], palette="rocket")
axes[2].set_title("Distribution of Discrepancy Types", fontsize=14, fontweight='bold')

plt.tight_layout()
plt.show()

# %%
iaa_report
# Out:
#                Annotator Pair  Sentences Compared  Perfect Matches  \
# 0  sasi.dimopoulou ↔ stalexan                 212              164
#
#   Sentence Match %  Span F1-Score
# 0            77.4%         0.9114

# %%
label_report
# Out:
#       Label  Both  Only in A (stalexan)  Only in B (sasi.dimopoulou)  F1-Score
# 0  LOCATION    44                     2                            2    0.9565
# 1  MATERIAL    92                     7                            8    0.9246
# 2   CONTEXT   231                    20                           18    0.9240
# 3    PERSON    24                     3                            1    0.9231
# 4    PERIOD    83                     8                            8    0.9121
# 5   FEATURE    79                     9                            7    0.9080
# 6  ARTEFACT   176                    21                           25    0.8844
# 7   SPECIES    17                     2                            4    0.8500
# 8   OVERALL   746                    72                           73    0.9114

# %%
discrepancy_report
# Out:
#                            Count
# Exact Matches             746.00
# Label Mismatches            4.00
# Boundary Disagreements     63.00
# Total Misses (A only)       5.00
# Total Misses (B only)       9.00
# Boundary Char Diff (Avg)    4.41

# %%
# Calculate macro-averaged F1-Score
macro_f1 = label_report[label_report["Label"] != "OVERALL"]["F1-Score"].mean()
print(f"Macro-averaged F1-Score: {macro_f1:.4f}")
# Out:
# Macro-averaged F1-Score: 0.9103

# %%
# Export results to Excel (in one file with different sheets)
file_name = "ArchaeoNER_Round_2_Final.xlsx"

with pd.ExcelWriter(file_name, engine="openpyxl") as writer:
    df.to_excel(writer, sheet_name="Annotated_Data", index=False)
    label_report.to_excel(writer, sheet_name="F1_Scores", index=False)
    discrepancy_report.to_excel(writer, sheet_name="Discrepancies")

print(f"Results saved to file: {file_name}")
# Out:
# Results saved to file: ArchaeoNER_Round_2_Final.xlsx
